# %% [markdown]
# 1. Pregunta teórica: ¿Qué diferencia existe entre la covarianza y la correlación?

# %% [markdown]
# - La correlación es cuando una variable nos da información acerca de la otra, lo que se mide es la fuerza de la relación. De la misma manera que la covarianza nos va a indicar si la relación entre dos variables está en el mismo sentido

# %% [markdown]
# 2. Calculad la covarianza y la correlación de nuestro dataset. No nos vale solo con que la calculéis, debéis hacer una interpretación de los resultados obtenidos. Calculad solo la correlación de Pearson.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] = (10,8) # para establecer el tamaño de todas las figuras del jupyter al mismo tamaño.

# %%
df = pd.read_csv("Datos/possum2.csv", index_col=0)
df.head()
# Out:
#    case  site  Pop sex  age  hdlngth  skullw  totlngth  taill  footlgth  \
# 0     1     1  Vic   m  8.0     94.1    60.4      89.0   36.0      74.5
# 1     2     1  Vic   f  6.0     92.5    57.6      91.5   36.5      72.5
# 2     3     1  Vic   f  6.0     94.0    60.0      95.5   39.0      75.4
# 3     4     1  Vic   f  6.0     93.2    57.1      92.0   38.0      76.1
# 4     5     1  Vic   f  2.0     91.5    56.3      85.5   36.0      71.0
#
#    earconch   eye  chest  belly
# 0      54.5  15.2   28.0   36.0
# 1      51.2  16.0   28.5   33.0
# 2      51.9  15.5   30.0   34.0
# 3      52.2  15.2   28.0   34.0
# 4      53.2  15.1   28.5   33.0

# %%
df.cov()
# Out:
#                 case       site        age    hdlngth     skullw   totlngth  \
# case      910.000000  68.762136 -10.966019 -22.548058 -11.746117 -43.473786
# site       68.762136   5.518204  -0.554612  -1.373665  -0.611044  -2.641262
# age       -10.966019  -0.554612   3.587659   2.177231   1.711548   2.160007
# hdlngth   -22.548058  -1.373665   2.177231  12.768827   7.908203  10.644985
# skullw    -11.746117  -0.611044   1.711548   7.908203   9.693420   7.064761
# totlngth  -43.473786  -2.641262   2.160007  10.644985   7.064761  18.580836
# taill      18.640777   1.751214   0.462939   2.012593   1.561324   4.777782
# footlgth -105.337379  -8.334587   1.210633   5.281610   3.767768   7.574141
# earconch  -95.914563  -7.633010   0.350336   1.783600  -0.006871   2.736475
# eye        -2.664078  -0.091262   0.476475   1.303069   1.052995   1.121897
# chest     -24.825243  -1.660194   1.310680   4.616019   4.010680   5.095631
# ...

# %%
sns.pairplot(df);

# %% [markdown]
# - La `covarianza` indica si ambas variables varían en la misma dirección (**covarianza positiva**, es decir, si aumenta el valor de una variable aumenta el variable de la otra) o en dirección opuesta (**covarianza negativa** cuando aumenta el valor de una de las variables, disminuye el de la otra). En este caso valor de la covarianza no es importante, solo el signo (si es positivo o negativo)
#
# hdlngth ---- chest --- parecen tener una covarianza positiva
#
# hdlngth ---- skullw --- parecen tener una covarianza positiva
#
# hdlngth ---- totlngth --- parecen tener una covarianza positiva

# %%
correlacion = ["pearson"]

for indice in correlacion: 
    print(f"------- La correlación de {indice} es: ")
    print(df.corr(method = indice)) # calculamos la correlación.
# Out:
# ------- La correlación de pearson es:
#               case      site       age   hdlngth    skullw  totlngth  \
# case      1.000000  0.970353 -0.191921 -0.209177 -0.125065 -0.334329
# site      0.970353  1.000000 -0.124648 -0.163646 -0.083548 -0.260843
# age      -0.191921 -0.124648  1.000000  0.321680  0.290232  0.264556
# hdlngth  -0.209177 -0.163646  0.321680  1.000000  0.710827  0.691094
# skullw   -0.125065 -0.083548  0.290232  0.710827  1.000000  0.526413
# totlngth -0.334329 -0.260843  0.264556  0.691094  0.526413  1.000000
# taill     0.315351  0.380444  0.124729  0.287429  0.255921  0.565646
# footlgth -0.731255 -0.743005  0.133849  0.309526  0.253427  0.367966
# earconch -0.773727 -0.790716  0.045009  0.121463 -0.000537  0.154484
# eye      -0.084078 -0.036987  0.239492  0.347175  0.321991  0.247786
# chest    -0.402303 -0.345494  0.338276  0.631498  0.629737  0.577890
# belly    -0.211671 -0.175266  0.350094  0.562663  0.451838  0.519465
#
# ...

# %% [markdown]
# 3. Con los resultados de la correlación del ejercicio anterior, cread un heatmap

# %%
sns.heatmap(df.corr(), 
            cmap = "YlGnBu",
           annot = True);

# %%
# creamos un dataframe todo de unos de la misma forma que nuestra matriz de correlación
mask = np.triu(np.ones_like(df.corr(), dtype=np.bool))
mask
# Out:
# /var/folders/4t/jwz4fg1j3ps9fv1187b_jzr40000gn/T/ipykernel_5706/2753540621.py:2: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.triu(np.ones_like(df.corr(), dtype=np.bool))
# array([[ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True],
#        [False,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True],
#        [False, False,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True],
#        [False, False, False,  True,  True,  True,  True,  True,  True,
#          True,  True,  True],
# ...

# %%
sns.heatmap(df.corr(),
            cmap = "YlGnBu", 
            mask = mask, # incorporamos la máscara en nuestro plot
           annot = True);

# %% [markdown]
# hdlngth ---- chest --- parecen tener una covarianza positiva y alta entre variables
#
# hdlngth ---- skullw --- parecen tener una covarianza positiva y alta entre variables
#
# hdlngth ---- totlngth --- parecen tener una covarianza positiva y alta entre variables

# %% [markdown]
# 4. Guardad la gráfica del heatmap, queda guardada en la carpeta de Datos como Grafica_Pearson_Possum
