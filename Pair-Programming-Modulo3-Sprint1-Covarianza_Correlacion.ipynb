# %% [markdown]
# 1. Pregunta teórica: ¿Qué diferencia existe entre la covarianza y la correlación?

# %% [markdown]
# - La correlación es cuando una variable nos da información acerca de la otra, lo que se mide es la fuerza de la relación. De la misma manera que la covarianza nos va a indicar si la relación entre dos variables está en el mismo sentido

# %% [markdown]
# 2. Calculad la covarianza y la correlación de nuestro dataset. No nos vale solo con que la calculéis, debéis hacer una interpretación de los resultados obtenidos. Calculad solo la correlación de Pearson.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] = (10,8) # para establecer el tamaño de todas las figuras del jupyter al mismo tamaño.

# %%
df = pd.read_csv("Datos/possum2.csv", index_col=0)
df.head()
# Out:
#       site  Pop sex  age  hdlngth  skullw  totlngth  taill  footlgth  \
# case
# 1        1  Vic   m  8.0     94.1    60.4      89.0   36.0      74.5
# 2        1  Vic   f  6.0     92.5    57.6      91.5   36.5      72.5
# 3        1  Vic   f  6.0     94.0    60.0      95.5   39.0      75.4
# 4        1  Vic   f  6.0     93.2    57.1      92.0   38.0      76.1
# 5        1  Vic   f  2.0     91.5    56.3      85.5   36.0      71.0
#
#       earconch   eye  chest  belly
# case
# 1         54.5  15.2   28.0   36.0
# 2         51.2  16.0   28.5   33.0
# 3         51.9  15.5   30.0   34.0
# 4         52.2  15.2   28.0   34.0
# 5         53.2  15.1   28.5   33.0

# %%
df.cov()
# Out:
#               site       age    hdlngth    skullw   totlngth     taill  \
# site      5.518204 -0.554612  -1.373665 -0.611044  -2.641262  1.751214
# age      -0.554612  3.587659   2.177231  1.711548   2.160007  0.462939
# hdlngth  -1.373665  2.177231  12.768827  7.908203  10.644985  2.012593
# skullw   -0.611044  1.711548   7.908203  9.693420   7.064761  1.561324
# totlngth -2.641262  2.160007  10.644985  7.064761  18.580836  4.777782
# taill     1.751214  0.462939   2.012593  1.561324   4.777782  3.839712
# footlgth -8.104988  0.995926   6.138564  3.782418   8.431650 -1.092538
# earconch -7.633010  0.350336   1.783600 -0.006871   2.736475 -3.101270
# eye      -0.091262  0.476475   1.303069  1.052995   1.121897  0.407804
# chest    -1.660194  1.310680   4.616019  4.010680   5.095631  0.701456
# belly    -1.137136  1.831497   5.553146  3.885409   6.184503  1.593820
#
#            footlgth   earconch       eye     chest     belly
# site      -8.104988  -7.633010 -0.091262 -1.660194 -1.137136
# age        0.995926   0.350336  0.476475  1.310680  1.831497
# hdlngth    6.138564   1.783600  1.303069  4.616019  5.553146
# skullw     3.782418  -0.006871  1.052995  4.010680  3.885409
# totlngth   8.431650   2.736475  1.121897  5.095631  6.184503
# taill     -1.092538  -3.101270  0.407804  0.701456  1.593820
# footlgth  19.318713  13.957339  0.024108  4.071078  3.680868
# earconch  13.957339  16.887005 -0.712599  1.674757  0.755078
# eye        0.024108  -0.712599  1.103286  0.320874  0.683831
# chest      4.071078   1.674757  0.320874  4.184466  3.424757
# belly      3.680868   0.755078  0.683831  3.424757  7.628361

# %%
sns.pairplot(df);

# %% [markdown]
# - La `covarianza` indica si ambas variables varían en la misma dirección (**covarianza positiva**, es decir, si aumenta el valor de una variable aumenta el variable de la otra) o en dirección opuesta (**covarianza negativa** cuando aumenta el valor de una de las variables, disminuye el de la otra). En este caso valor de la covarianza no es importante, solo el signo (si es positivo o negativo)
#
# age ---- belly --- parecen tener una covarianza positiva
# age ---- chest --- parecen tener una covarianza positiva
# age ---- hdlngth --- parecen tener una covarianza positiva

# %%
correlacion = ["pearson"]

for indice in correlacion: 
    print(f"------- La correlación de {indice} es: ")
    print(df.corr(method = indice)) # calculamos la correlación.
# Out:
# ------- La correlación de pearson es:
#               site       age   hdlngth    skullw  totlngth     taill  \
# site      1.000000 -0.124648 -0.163646 -0.083548 -0.260843  0.380444
# age      -0.124648  1.000000  0.321680  0.290232  0.264556  0.124729
# hdlngth  -0.163646  0.321680  1.000000  0.710827  0.691094  0.287429
# skullw   -0.083548  0.290232  0.710827  1.000000  0.526413  0.255921
# totlngth -0.260843  0.264556  0.691094  0.526413  1.000000  0.565646
# taill     0.380444  0.124729  0.287429  0.255921  0.565646  1.000000
# footlgth -0.783009  0.119274  0.391605  0.275059  0.444832 -0.126277
# earconch -0.790716  0.045009  0.121463 -0.000537  0.154484 -0.385136
# eye      -0.036987  0.239492  0.347175  0.321991  0.247786  0.198134
# chest    -0.345494  0.338276  0.631498  0.629737  0.577890  0.174997
# belly    -0.175266  0.350094  0.562663  0.451838  0.519465  0.294493
#
#           footlgth  earconch       eye     chest     belly
# site     -0.783009 -0.790716 -0.036987 -0.345494 -0.175266
# age       0.119274  0.045009  0.239492  0.338276  0.350094
# hdlngth   0.391605  0.121463  0.347175  0.631498  0.562663
# skullw    0.275059 -0.000537  0.321991  0.629737  0.451838
# totlngth  0.444832  0.154484  0.247786  0.577890  0.519465
# taill    -0.126277 -0.385136  0.198134  0.174997  0.294493
# footlgth  1.000000  0.783050  0.005213  0.450590  0.302584
# earconch  0.783050  1.000000 -0.165092  0.199230  0.066527
# eye       0.005213 -0.165092  1.000000  0.149338  0.235716
# chest     0.450590  0.199230  0.149338  1.000000  0.606170
# belly     0.302584  0.066527  0.235716  0.606170  1.000000

# %% [markdown]
# 3. Con los resultados de la correlación del ejercicio anterior, cread un heatmap

# %%
sns.heatmap(df.corr(), 
            cmap = "YlGnBu",
           annot = True);

# %%
# creamos un dataframe todo de unos de la misma forma que nuestra matriz de correlación
mask = np.triu(np.ones_like(df.corr(), dtype=np.bool))
mask
# Out:
# /tmp/ipykernel_37533/2753540621.py:2: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.triu(np.ones_like(df.corr(), dtype=np.bool))
# array([[ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True],
#        [False,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True],
#        [False, False,  True,  True,  True,  True,  True,  True,  True,
#          True,  True],
#        [False, False, False,  True,  True,  True,  True,  True,  True,
#          True,  True],
#        [False, False, False, False,  True,  True,  True,  True,  True,
#          True,  True],
#        [False, False, False, False, False,  True,  True,  True,  True,
#          True,  True],
#        [False, False, False, False, False, False,  True,  True,  True,
#          True,  True],
#        [False, False, False, False, False, False, False,  True,  True,
#          True,  True],
#        [False, False, False, False, False, False, False, False,  True,
#          True,  True],
#        [False, False, False, False, False, False, False, False, False,
#          True,  True],
#        [False, False, False, False, False, False, False, False, False,
#         False,  True]])

# %%
sns.heatmap(df.corr(),
            cmap = "YlGnBu", 
            mask = mask, # incorporamos la máscara en nuestro plot
           annot = True);

# %% [markdown]
#  - age ---- belly --- Existe una correlación positiva y moderada entre variables
#
#  - age ---- chest --- Existe una correlación positiva y moderada entre variables
#
# - age ---- hdlngth --- Existe una correlación positiva y moderada entre variables

# %% [markdown]
# 4. Guardad la gráfica del heatmap, queda guardada en la carpeta de Datos como Grafica_Pearson_Possum
